# %% [markdown]
# # **Проект №7. Отток клиентов из банка** <a class="tocSkip">

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1">Описание проекта</a></span></li><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-2">Импорт библиотек</a></span></li><li><span><a href="#Функции" data-toc-modified-id="Функции-3">Функции</a></span></li><li><span><a href="#Общая-информация-о-данных-и-их-подготовка" data-toc-modified-id="Общая-информация-о-данных-и-их-подготовка-4">Общая информация о данных и их подготовка</a></span><ul class="toc-item"><li><span><a href="#Удаление-колонок" data-toc-modified-id="Удаление-колонок-4.1">Удаление колонок</a></span></li><li><span><a href="#Переименование-колонок" data-toc-modified-id="Переименование-колонок-4.2">Переименование колонок</a></span></li><li><span><a href="#Анализ-пропусков" data-toc-modified-id="Анализ-пропусков-4.3">Анализ пропусков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-4.4">Изменение типов данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5">Вывод</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-5">Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1">Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных-к-обучению" data-toc-modified-id="Подготовка-данных-к-обучению-6">Подготовка данных к обучению</a></span><ul class="toc-item"><li><span><a href="#Прямое-кодирование" data-toc-modified-id="Прямое-кодирование-6.1">Прямое кодирование</a></span></li><li><span><a href="#Разделение-на-выборки" data-toc-modified-id="Разделение-на-выборки-6.2">Разделение на выборки</a></span></li><li><span><a href="#Стандартизация" data-toc-modified-id="Стандартизация-6.3">Стандартизация</a></span></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-6.4">Борьба с дисбалансом</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.5">Вывод</a></span></li></ul></li><li><span><a href="#Моделирование" data-toc-modified-id="Моделирование-7">Моделирование</a></span><ul class="toc-item"><li><span><a href="#Данные-с-дисбалансом-классов" data-toc-modified-id="Данные-с-дисбалансом-классов-7.1">Данные с дисбалансом классов</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-7.1.1">Дерево решений</a></span></li><li><span><a href="#Случайны-лес" data-toc-modified-id="Случайны-лес-7.1.2">Случайны лес</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-7.1.3">Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Промежуточные-итоги" data-toc-modified-id="Промежуточные-итоги-7.2">Промежуточные итоги</a></span></li><li><span><a href="#Сбалансированные-данные" data-toc-modified-id="Сбалансированные-данные-7.3">Сбалансированные данные</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-7.3.1">Дерево решений</a></span></li><li><span><a href="#Случайны-лес" data-toc-modified-id="Случайны-лес-7.3.2">Случайны лес</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-7.3.3">Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Иготи-обучения" data-toc-modified-id="Иготи-обучения-7.4">Иготи обучения</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-8">Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-9">Вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых. Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Нам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Построим модель с предельно большим значением *F1*-меры. Чтобы считать проект успешно, доведем метрику до 0.59.
# Дополнительно измерим AUC-ROC, сравнивая её значение с F1-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)
#
# **Описание данных**
#
# Признаки:
# - `RowNumber` — индекс строки в данных
# - `CustomerId` — уникальный идентификатор клиента
# - `Surname` — фамилия
# - `CreditScore` — кредитный рейтинг
# - `Geography` — страна проживания
# - `Gender` — пол
# - `Age` — возраст
# - `Tenure` — сколько лет человек является клиентом банка
# - `Balance` — баланс на счёте
# - `NumOfProducts` — количество продуктов банка, используемых клиентом
# - `HasCrCard` — наличие кредитной карты
# - `IsActiveMember` — активность клиента
# - `EstimatedSalary` — предполагаемая зарплата
#
# Целевой признак:
# - `Exited` — факт ухода клиента

# %% [markdown]
# ##  Импорт библиотек

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mlt
import matplotlib.pyplot as plt
import math

from sklearn.tree import DecisionTreeClassifier      # Деревья решений
from sklearn.ensemble import RandomForestClassifier  # Случайный лес
from sklearn.linear_model import LogisticRegression  # Логистическая регрессия
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score, roc_curve, precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
sns.set(rc={'figure.figsize': (5, 3)})
pd.set_option('display.float_format', '{:.2f}'.format)
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ##  Функции

# %%
# Для проверки общей информации по таблице
def info_data(df):
    print('\n', '\033[1m'+'Общая информация по таблице:'+'\033[0m')
    try:
        df.info(show_counts=False)
    except:
        df.info(null_counts=False)

    print('\n', 'Слуйчайные строки из таблицы:')
    if df.shape[0] < 5:
        display(df.sample(df.shape[0]))
    else:
        display(df.sample(5))

    print('\n', 'Статистика числовых параметров:')
    display(df.describe().T)

    if 'object' in df.dtypes.to_list():
        print('\n', 'Статистика строковых параметров:')
        display(df.describe(include='object').T)
    else:
        print('\n', 'В данных отсутствуют строковые значения')

    print('\n', 'Статистика пропусков в данных:')
    display(df.isna()
              .agg(['sum', 'mean']).T
              .rename(columns={'sum': 'Кол-во пропусков',
                               'mean': '% пропусков'})
              .sort_values('% пропусков', ascending=False)
              .style.format({'Кол-во пропусков': '{:,.0f}'.format,
                             '% пропусков': '{:,.1%}'.format}))

    print('\n', 'Количество явных дубликатов:', df.duplicated().sum())


# Для изменеия типов данных в колонках
def change_the_type(df, list_columns, typ):
    for i in list_columns:
        df[i] = df[i].astype(typ)
    display(df[list_columns].dtypes)
    print()


    # Для балансировки целевого признака, путем увеличения выборки
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    features_upsampled, target_upsampled = shuffle(features_upsampled, target_upsampled, random_state=42)
    
    return features_upsampled, target_upsampled


# Для балансировки целевого признака, путем уменьшения выборки
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat([features_zeros.sample(frac=fraction, random_state=42)] + [features_ones])
    target_downsampled = pd.concat([target_zeros.sample(frac=fraction, random_state=42)] + [target_ones])
    features_downsampled, target_downsampled = shuffle(features_downsampled, target_downsampled, random_state=42)
    
    return features_downsampled, target_downsampled


# Обучение дерева решений
def learning_tree(features_train, target_train, features_valid, target_valid, name_col):
    best_model = None
    best_result = 0
    df_result = pd.DataFrame()

    for depth in range(1, 19):
        model = DecisionTreeClassifier(random_state=42, max_depth=depth)
        model.fit(features_train, target_train)                     
        predictions = model.predict(features_valid)                           
        result = f1_score(target_valid, predictions)
        new_row = [depth, result]
        new_df = pd.DataFrame(data=new_row, index=['depth', 'F1']).T
        df_result = pd.concat([df_result, new_df], ignore_index=True)
        if result > best_result:
            best_depth = depth
            best_model = model
            best_result = result
            precision = precision_score(target_valid, predictions, zero_division=0)
            accuracy = accuracy_score(target_valid , predictions)
            recall = recall_score(target_valid, predictions)
            probabilities_valid = model.predict_proba(features_valid)
            probabilities_one_valid = probabilities_valid[:, 1]
            roc_auc = roc_auc_score(target_valid, probabilities_one_valid)

    print(f'''Лучшая модель решающего дерева с глубиной равной {best_depth}
     Accuracy: {accuracy:.3f}
    Precision: {precision:.3f}
       Recall: {recall:.3f}
           F1: {best_result:.3f}
      AUC-ROC: {roc_auc:.3f}''')

    best_result_model.loc[:, (name_col, 'decision_tree')]= [accuracy, precision, recall, result, roc_auc]

    plt.plot('depth', 'F1', data = df_result)
    plt.title('Точность дерева решений')
    plt.xlabel('Глубина дерева')
    plt.ylabel('Значение F1')
    plt.show()

    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 

    plt.figure()
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая')
    plt.show()


# Обучение случайного леса
def learning_forest(features_train, target_train, features_valid, target_valid, name_col):
    best_model = None
    best_result = 0
    df_result = pd.DataFrame()
    for est in range(1, 56, 5):
        for depth in range(1, 35):
            model = RandomForestClassifier(random_state=42, n_estimators=est, max_depth=depth)
            model.fit(features_train, target_train)                     
            predictions = model.predict(features_valid)                           
            result = f1_score(target_valid, predictions)
            new_row = [depth, est, result]
            new_df = pd.DataFrame(data=new_row, index=['depth', 'est', 'F1']).T
            df_result = pd.concat([df_result, new_df], ignore_index=True)
            if result > best_result:
                best_model = model
                best_result = result
                best_depth = depth
                best_est = est
                precision = precision_score(target_valid, predictions, zero_division=0)
                recall = recall_score(target_valid, predictions)
                accuracy = accuracy_score(target_valid , predictions)
                probabilities_valid = model.predict_proba(features_valid)
                probabilities_one_valid = probabilities_valid[:, 1]
                roc_auc = roc_auc_score(target_valid, probabilities_one_valid)

    print(f'''Лучшая модель: {best_model}
     Accuracy: {accuracy:.3f}
    Precision: {precision:.3f}
       Recall: {recall:.3f}
           F1: {best_result:.3f}
      AUC-ROC: {roc_auc:.3f}''')

    best_result_model.loc[:, (name_col, 'random_forest')]= [accuracy, precision, recall, result, roc_auc]

    df_result.pivot_table(index ='depth', columns='est', values ='F1').plot(figsize = (10, 5))
    plt.title('Точность случайного леса по количеству деревьев')
    plt.xlabel('Глубина дерева')
    plt.ylabel('Значение F1')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 

    plt.figure()
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая')
    plt.show()


# Обучение логистической регрессии
def learning_logreg(features_train, target_train, features_valid, target_valid, name_col):
    model = LogisticRegression(random_state=42)
    model.fit(features_train, target_train)                     
    predictions = model.predict(features_valid)                           
    result = f1_score(target_valid, predictions)
    precision = precision_score(target_valid, predictions, zero_division=0)
    recall = recall_score(target_valid, predictions)
    accuracy = accuracy_score(target_valid , predictions)  
    probabilities_valid = model.predict_proba(features_valid)
    probabilities_one_valid = probabilities_valid[:, 1]
    roc_auc = roc_auc_score(target_valid, probabilities_one_valid)

    print(f'''Accuracy: {accuracy:.3f}
    Precision: {precision:.3f}
       Recall: {recall:.3f}
           F1: {result:.3f}
      AUC-ROC: {roc_auc:.3f}''')

    best_result_model.loc[:, (name_col, 'logistic_regression')]= [accuracy, precision, recall, result, roc_auc]

    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 

    plt.figure()
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая')
    plt.show()

# %% [markdown]
# ## Общая информация о данных и их подготовка

# %%
try:
    df = pd.read_csv('Churn.csv', index_col='RowNumber')
except:
    df = pd.read_csv('/datasets/Churn.csv', index_col='RowNumber')
info_data(df)
# Out:
#  Общая информация по таблице:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   CustomerId       int64
#  1   Surname          object
#  2   CreditScore      int64
#  3   Geography        object
#  4   Gender           object
#  5   Age              int64
#  6   Tenure           float64
#  7   Balance          float64
#  8   NumOfProducts    int64
#  9   HasCrCard        int64
#  10  IsActiveMember   int64
#  11  EstimatedSalary  float64
#  12  Exited           int64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 1.1+ MB
#
#  Слуйчайные строки из таблицы:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 4602         15571666       Shaw          642   Germany    Male   30    8.00
# 1368         15627232    Jibunoh          608   Germany    Male   44    7.00
# ...

# %% [markdown]
# В первую очередь замечаем, что колонки правильней будет привести к змеиному регистру. Так же в данных имеются колонки, которые не нужны для обучения моделей, напрмиер фамилия и, если каждой строке соответствует 1 клиент, то и уникальный номер клиента нам не к чему. В данных имеются пропуски в колонке `Tenure`, необходимо посмотреть из-за чего они могут быть и попытаться их востановить, в противном случаи удалить пропуски из колонки. Ну и неплохо было бы изменить тип данных на менее ресурсо затратный.

# %%
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# Каких-то сильных выбросов в данных не видно.

# %% [markdown]
# ### Удаление колонок

# %%
df['CustomerId'].nunique()
# Out:
# 10000

# %% [markdown]
# Каждй строке соответствует уникальный клиент, поэтому этой колонкой можно пренебречь (или испльзовать как индекс). Но мы просто удалим ее.

# %%
df.drop(['CustomerId', 'Surname'], axis = 1, inplace = True)

# %% [markdown]
# ### Переименование колонок

# %%
list(df.columns)
# Out:
# ['CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
list_name = list(df.columns)
list_name_low = []
for name in list_name:
    snake_register = ''
    for i in name:
        if i.isupper():
            snake_register += '_' + i.lower()
        else:
            snake_register += i
    list_name_low.append(snake_register.lstrip('_'))
list_name_low
# Out:
# ['credit_score',
#  'geography',
#  'gender',
#  'age',
#  'tenure',
#  'balance',
#  'num_of_products',
#  'has_cr_card',
#  'is_active_member',
#  'estimated_salary',
#  'exited']

# %%
df.columns = list_name_low
list(df.columns)
# Out:
# ['credit_score',
#  'geography',
#  'gender',
#  'age',
#  'tenure',
#  'balance',
#  'num_of_products',
#  'has_cr_card',
#  'is_active_member',
#  'estimated_salary',
#  'exited']

# %% [markdown]
# ### Анализ пропусков

# %% [markdown]
# Главный вопрос с пропусками: как именно их обработать? Удлаить, заполнить медианой или заполнить случайным числом в зависимости от распределения значения.

# %%
df['tenure'].hist()
plt.title('Распределение продолжительности пользования услугами')
plt.xlabel('Количество лет ')
plt.ylabel('Количество клиентов')
plt.show()

# %%
df[df['tenure'].isna()].drop('tenure', axis = 1).hist(figsize=(10,10))
plt.show()

# %% [markdown]
# Какой-либо закономерности не видно, поэтому просто заполним пустые значения медианой.

# %%
df['tenure'] = df['tenure'].fillna(df['tenure'].median())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   geography         10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  float64
#  5   balance           10000 non-null  float64
#  6   num_of_products   10000 non-null  int64
#  7   has_cr_card       10000 non-null  int64
#  8   is_active_member  10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  exited            10000 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 937.5+ KB

# %%
df['balance'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Изменение типов данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   geography         10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  float64
#  5   balance           10000 non-null  float64
#  6   num_of_products   10000 non-null  int64
#  7   has_cr_card       10000 non-null  int64
#  8   is_active_member  10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  exited            10000 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 937.5+ KB

# %%
df.describe().T
# Out:
#                     count      mean      std    min      25%       50%  \
# credit_score     10000.00    650.53    96.65 350.00   584.00    652.00
# age              10000.00     38.92    10.49  18.00    32.00     37.00
# tenure           10000.00      5.00     2.76   0.00     3.00      5.00
# balance          10000.00  76485.89 62397.41   0.00     0.00  97198.54
# num_of_products  10000.00      1.53     0.58   1.00     1.00      1.00
# has_cr_card      10000.00      0.71     0.46   0.00     0.00      1.00
# is_active_member 10000.00      0.52     0.50   0.00     0.00      1.00
# estimated_salary 10000.00 100090.24 57510.49  11.58 51002.11 100193.91
# exited           10000.00      0.20     0.40   0.00     0.00      0.00
#
#                        75%       max
# credit_score        718.00    850.00
# age                  44.00     92.00
# tenure                7.00     10.00
# balance          127644.24 250898.09
# num_of_products       2.00      4.00
# ...

# %% [markdown]
# В данных имеется 6 колонок без отрацательных значений, с целыми значениями, не превышая значени 250, поэтому из приводит к типу `uint8`.
# `credit_score` оптимально будет привести к `float16`.
# А `balance` и `estimated_salary` к `float32`.
# Колонки `geography` и `gender` приведем к типу `category`.

# %%
list_iunt8 = ['age', 'tenure', 'num_of_products', 'has_cr_card', 'is_active_member', 'exited']
change_the_type(df, list_iunt8, 'uint8')
change_the_type(df, ['credit_score'], 'float16')
change_the_type(df, ['balance', 'estimated_salary'], 'float32')
change_the_type(df, ['geography', 'gender'], 'category')
# Out:
# age                 uint8
# tenure              uint8
# num_of_products     uint8
# has_cr_card         uint8
# is_active_member    uint8
# exited              uint8
# dtype: object
# credit_score    float16
# dtype: object
# balance             float32
# estimated_salary    float32
# dtype: object
# geography    category
# gender       category
# dtype: object

# %% [markdown]
# Проверим значения.

# %%
df.describe().T
# Out:
#                     count      mean      std    min      25%       50%  \
# credit_score     10000.00       inf      inf 350.00   584.00    652.00
# age              10000.00     38.92    10.49  18.00    32.00     37.00
# tenure           10000.00      5.00     2.76   0.00     3.00      5.00
# balance          10000.00  76485.89 62397.41   0.00     0.00  97198.54
# num_of_products  10000.00      1.53     0.58   1.00     1.00      1.00
# has_cr_card      10000.00      0.71     0.46   0.00     0.00      1.00
# is_active_member 10000.00      0.52     0.50   0.00     0.00      1.00
# estimated_salary 10000.00 100090.23 57510.49  11.58 51002.11 100193.91
# exited           10000.00      0.20     0.40   0.00     0.00      0.00
#
#                        75%       max
# credit_score        718.00    850.00
# age                  44.00     92.00
# tenure                7.00     10.00
# balance          127644.24 250898.09
# num_of_products       2.00      4.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  float16
#  1   geography         10000 non-null  category
#  2   gender            10000 non-null  category
#  3   age               10000 non-null  uint8
#  4   tenure            10000 non-null  uint8
#  5   balance           10000 non-null  float32
#  6   num_of_products   10000 non-null  uint8
#  7   has_cr_card       10000 non-null  uint8
#  8   is_active_member  10000 non-null  uint8
#  9   estimated_salary  10000 non-null  float32
#  10  exited            10000 non-null  uint8
# dtypes: category(2), float16(1), float32(2), uint8(6)
# memory usage: 254.2 KB

# %% [markdown]
# Такими нехитрыми способами нам удалось снизить используемую память в 4 раза.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Данные предоставлены в достаточно хорошем состоянии
# - Пропуски были заменены медианой
# - Название колонок было изменено на змеиный регистр
# - Из данных были удалены ненужные колонки
# - Удалось снизить потребляемую память в 4 раза

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# Посмотрим на корреляцию в данных

# %% [raw]
# sns.pairplot(data=df)
# plt.show()

# %% [raw]
# pd.plotting.scatter_matrix(df)
# plt.show()

# %%
df.corr().style.format('{:.2f}').background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_5ff9c_row0_col0, #T_5ff9c_row1_col1, #T_5ff9c_row2_col2, #T_5ff9c_row3_col3, #T_5ff9c_row4_col4, #T_5ff9c_row5_col5, #T_5ff9c_row6_col6, #T_5ff9c_row7_col7, #T_5ff9c_row8_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_5ff9c_row0_col1, #T_5ff9c_row2_col0, #T_5ff9c_row3_col7, #T_5ff9c_row4_col7, #T_5ff9c_row7_col0 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_5ff9c_row0_col2 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_5ff9c_row0_col3, #T_5ff9c_row3_col8, #T_5ff9c_row5_col4 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_5ff9c_row0_col4, #T_5ff9c_row7_col3, #T_5ff9c_row7_col4 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_5ff9c_row0_col5, #T_5ff9c_row0_col7 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_5ff9c_row0_col6 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_5ff9c_row0_col8, #T_5ff9c_row2_col6, #T_5ff9c_row6_col1 {
# ...

# %%
sns.heatmap(df.corr(), center=0, linewidths=.5, cmap="coolwarm");

# %% [markdown]
# Как видно никаких корреляций в данных нет.

# %%
exited_values = pd.concat([df['exited'].value_counts(), 
                           df['exited'].value_counts()/df.shape[0]], 
                          axis=1)
exited_values.columns=['Количество', 'Доля']
exited_values
# Out:
#    Количество  Доля
# 0        7963  0.80
# 1        2037  0.20

# %% [markdown]
# А вот дисбаланс целевого признака имеется имеется. Количество клиентов, которые ушли из банка в 4 раза меньше остальных.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - В данных нет параметров, которые бы коррелировали друг с другом
# - В данных присутствует дисбаланс целевого признака (1 класса больше в 4 раза чем 0)

# %% [markdown]
# ## Подготовка данных к обучению

# %% [markdown]
# ### Прямое кодирование

# %% [markdown]
# Перед обучением применим прямое кодирование для категориальных признаков

# %%
df_ohe = pd.get_dummies(df, drop_first=True)
df_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit_score       10000 non-null  float16
#  1   age                10000 non-null  uint8
#  2   tenure             10000 non-null  uint8
#  3   balance            10000 non-null  float32
#  4   num_of_products    10000 non-null  uint8
#  5   has_cr_card        10000 non-null  uint8
#  6   is_active_member   10000 non-null  uint8
#  7   estimated_salary   10000 non-null  float32
#  8   exited             10000 non-null  uint8
#  9   geography_Germany  10000 non-null  uint8
#  10  geography_Spain    10000 non-null  uint8
#  11  gender_Male        10000 non-null  uint8
# dtypes: float16(1), float32(2), uint8(9)
# memory usage: 263.7 KB

# %% [markdown]
# ### Разделение на выборки

# %% [markdown]
# Теперь разделим данные на тестовую, валдиационную и обучающую выборки

# %%
df_train_all, df_test = train_test_split(df_ohe, test_size=0.2, random_state=42) 
df_train, df_valid = train_test_split(df_train_all, test_size=0.2, random_state=42) 
print('df_test: ', df_test.shape[0])
print('df_valid: ', df_valid.shape[0])
print('df_train: ', df_train.shape[0])

features_test = df_test.drop('exited', axis=1)
target_test = df_test['exited']

features_valid = df_valid.drop('exited', axis=1)
target_valid = df_valid['exited']

features_train = df_train.drop('exited', axis=1)
target_train = df_train['exited']
# Out:
# df_test:  2000
# df_valid:  1600
# df_train:  6400

# %% [markdown]
# ### Стандартизация

# %% [markdown]
# Теперь стандартизируем, все параметры кроме дамми переменных

# %%
df.describe().T
# Out:
#                     count      mean      std    min      25%       50%  \
# credit_score     10000.00       inf      inf 350.00   584.00    652.00
# age              10000.00     38.92    10.49  18.00    32.00     37.00
# tenure           10000.00      5.00     2.76   0.00     3.00      5.00
# balance          10000.00  76485.89 62397.41   0.00     0.00  97198.54
# num_of_products  10000.00      1.53     0.58   1.00     1.00      1.00
# has_cr_card      10000.00      0.71     0.46   0.00     0.00      1.00
# is_active_member 10000.00      0.52     0.50   0.00     0.00      1.00
# estimated_salary 10000.00 100090.23 57510.49  11.58 51002.11 100193.91
# exited           10000.00      0.20     0.40   0.00     0.00      0.00
#
#                        75%       max
# credit_score        718.00    850.00
# age                  44.00     92.00
# tenure                7.00     10.00
# balance          127644.24 250898.09
# num_of_products       2.00      4.00
# ...

# %%
numeric = ['credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'estimated_salary']
scaler = StandardScaler()
scaler.fit(features_train[numeric]) 

features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric]) 
features_test[numeric]  = scaler.transform(features_test[numeric])

# %% [markdown]
# ### Борьба с дисбалансом

# %% [markdown]
# Посмотри на распределение целевого признака в тренировочной выборке

# %%
target_train.value_counts()
# Out:
# 0    5083
# 1    1317
# Name: exited, dtype: int64

# %% [markdown]
# Соотношение примерно такое же как и в общих данных, поэтому увеличим соответственно первый класс (значение 1) в 4 раза

# %%
features_upsampled, target_upsampled = upsample(features_train, target_train, 4)
target_upsampled.value_counts()
# Out:
# 1    5268
# 0    5083
# Name: exited, dtype: int64

# %% [markdown]
# Отлично, теперь первого класса больше чем нулевого.
#
# Теперь сделаем еще 1 вариант данных, но уже способом уменьшения 0 класса

# %%
features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)
target_downsampled.value_counts()
# Out:
# 1    1317
# 0    1271
# Name: exited, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Категориальные данные были преобразованы в дамми переменные с помощью прямого кодировани
# - Данные было разделены на тестовую, валидационную и обучающую выборки
# - Числовые значения (кроме дамми переменных) были стандартизированы
# - Сдела дополнительная тренировочная выборка без дисбаланса классов

# %% [markdown]
# ## Моделирование

# %% [markdown]
# Теперь приступим непосредственно к моделированию и обучению моделей машинного обучения. Попробуем провести обучения в 2 вариантах, с учетом дисбаланса и без него.
#
# Создадим пустой датафрейм для того, чтобы складывать туда результаты моделей

# %%
best_result_model = pd.DataFrame(columns=pd.MultiIndex.from_product([['imbalance', 'upsample', 'downsample'],
                                                                     ['decision_tree',
                                                                      'random_forest',
                                                                      'logistic_regression']]),
                                 index=['Accuracy', 'Precision', 'Recall', 'F1', 'AUC-ROC'])

# %% [markdown]
# Ну и так же посмотрим на баланс целевого признака валидационной выборки для справки.

# %%
target_valid.value_counts()
# Out:
# 0    1273
# 1     327
# Name: exited, dtype: int64

# %% [markdown]
# Далее проведем обучение по 3 популярным алгоритмам машинного обучения и последующим подведением итогов

# %% [markdown]
# ### Данные с дисбалансом классов

# %% [markdown]
# #### Дерево решений

# %%
name_col = 'imbalance'

# %%
learning_tree(features_train, target_train, features_valid, target_valid, name_col)
# Out:
# Лучшая модель решающего дерева с глубиной равной 5
#      Accuracy: 0.856
#     Precision: 0.705
#        Recall: 0.505
#            F1: 0.588
#       AUC-ROC: 0.841

# %% [markdown]
# #### Случайны лес

# %%
learning_forest(features_train, target_train, features_valid, target_valid, name_col)
# Out:
# Лучшая модель: RandomForestClassifier(max_depth=22, n_estimators=41, random_state=42)
#      Accuracy: 0.866
#     Precision: 0.758
#        Recall: 0.508
#            F1: 0.608
#       AUC-ROC: 0.855

# %% [markdown]
# #### Логистическая регрессия

# %%
learning_logreg(features_train, target_train, features_valid, target_valid, name_col)
# Out:
# Accuracy: 0.811
#     Precision: 0.613
#        Recall: 0.208
#            F1: 0.311
#       AUC-ROC: 0.787

# %% [markdown]
# ### Промежуточные итоги

# %%
best_result_model.T
# Out:
#                                Accuracy Precision Recall   F1 AUC-ROC
# imbalance  decision_tree           0.86      0.71   0.50 0.51    0.84
#            random_forest           0.87      0.76   0.51 0.58    0.85
#            logistic_regression     0.81      0.61   0.21 0.31    0.79
# upsample   decision_tree            NaN       NaN    NaN  NaN     NaN
#            random_forest            NaN       NaN    NaN  NaN     NaN
#            logistic_regression      NaN       NaN    NaN  NaN     NaN
# downsample decision_tree            NaN       NaN    NaN  NaN     NaN
#            random_forest            NaN       NaN    NaN  NaN     NaN
#            logistic_regression      NaN       NaN    NaN  NaN     NaN

# %% [markdown]
# Как можно заметить на несбалансированной выборе лучше по всем показателям обучилась модель случайного леса. Посмотри как обучение пройдет на сбалансированной выборке

# %% [markdown]
# ### Сбалансированные данные

# %% [markdown]
# #### Дерево решений

# %%
learning_tree(features_upsampled, target_upsampled, features_valid, target_valid, 'upsample')
# Out:
# Лучшая модель решающего дерева с глубиной равной 6
#      Accuracy: 0.754
#     Precision: 0.443
#        Recall: 0.792
#            F1: 0.568
#       AUC-ROC: 0.847

# %%
learning_tree(features_downsampled, target_downsampled, features_valid, target_valid, 'downsample')
# Out:
# Лучшая модель решающего дерева с глубиной равной 5
#      Accuracy: 0.829
#     Precision: 0.571
#        Recall: 0.648
#            F1: 0.607
#       AUC-ROC: 0.837

# %% [markdown]
# #### Случайны лес

# %%
learning_forest(features_upsampled, target_upsampled, features_valid, target_valid, 'upsample')
# Out:
# Лучшая модель: RandomForestClassifier(max_depth=23, n_estimators=31, random_state=42)
#      Accuracy: 0.861
#     Precision: 0.677
#        Recall: 0.615
#            F1: 0.644
#       AUC-ROC: 0.851

# %%
learning_forest(features_downsampled, target_downsampled, features_valid, target_valid, 'downsample')
# Out:
# Лучшая модель: RandomForestClassifier(max_depth=10, n_estimators=51, random_state=42)
#      Accuracy: 0.797
#     Precision: 0.502
#        Recall: 0.780
#            F1: 0.611
#       AUC-ROC: 0.861

# %% [markdown]
# #### Логистическая регрессия

# %%
learning_logreg(features_upsampled, target_upsampled, features_valid, target_valid, 'upsample')
# Out:
# Accuracy: 0.722
#     Precision: 0.402
#        Recall: 0.743
#            F1: 0.522
#       AUC-ROC: 0.790

# %%
learning_logreg(features_downsampled, target_downsampled, features_valid, target_valid, 'downsample')
# Out:
# Accuracy: 0.724
#     Precision: 0.404
#        Recall: 0.743
#            F1: 0.524
#       AUC-ROC: 0.787

# %% [markdown]
# ### Иготи обучения

# %% [markdown]
# Посмотрим какой результат даст примитивный алгоритм DummyClassifier

# %%
strategies = ['most_frequent', 'prior', 'stratified', 'uniform']
dummy_results = pd.DataFrame(columns=['Accuracy'])

for strategy in strategies:
    dc = DummyClassifier(strategy = strategy, random_state = 42)
    dc.fit(features_train, target_train)
    result = dc.score(features_valid, target_valid)
    dummy_results.loc[strategy] = result
dummy_results
# Out:
#                Accuracy
# most_frequent      0.80
# prior              0.80
# stratified         0.67
# uniform            0.50

# %% [markdown]
# Исходя из этой таблицы делаем вывод, что любой алгоритм, который справляется с результатом Accuracy меньше 0.8 нам по определению не подходит и не может использоваться для нашей задачи.
#
# Теперь выведем итоговую таблицу со всеми результати обучения

# %%
best_result_model.T.style.format('{:.4f}').background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_72a56_row0_col0 {
#   background-color: #952f03;
#   color: #f1f1f1;
# }
# #T_72a56_row0_col1, #T_72a56_row1_col3 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_72a56_row0_col2 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_72a56_row0_col3 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_72a56_row0_col4 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_72a56_row1_col0, #T_72a56_row1_col1, #T_72a56_row3_col2, #T_72a56_row4_col3, #T_72a56_row7_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_72a56_row1_col2 {
#   background-color: #fc8937;
#   color: #f1f1f1;
# }
# #T_72a56_row1_col4 {
#   background-color: #9a3103;
#   color: #f1f1f1;
# }
# #T_72a56_row2_col0 {
#   background-color: #f26b15;
#   color: #f1f1f1;
# }
# #T_72a56_row2_col1 {
#   background-color: #f4721e;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Как видно на итоговой таблице наилучшим результатом по метрике F1 является "случайный лес" на сбалансированной выборке данных методом upsample. Ее и выберем для финального тестировнаия на тестовой выборке.

# %% [markdown]
# ## Тестирование модели

# %%
model = RandomForestClassifier(max_depth=23, n_estimators=31, random_state=42)
model.fit(features_upsampled, target_upsampled)                     
predictions = model.predict(features_test)                           
result = accuracy_score(target_test , predictions)
precision = precision_score(target_test, predictions, zero_division=0)
recall = recall_score(target_test, predictions)
f1 = f1_score(target_test, predictions)
probabilities_test = model.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]
roc_auc = roc_auc_score(target_test, probabilities_one_test)

print(f'''Параметры случайного леса на тестовой выборке:
 Accuracy: {result:.3f}
Precision: {precision:.3f}
   Recall: {recall:.3f}
       F1: {f1:.3f}
  AUC-ROC: {roc_auc:.3f}''')

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test) 

plt.figure()
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.show()
# Out:
# Параметры случайного леса на тестовой выборке:
#  Accuracy: 0.850
# Precision: 0.627
#    Recall: 0.578
#        F1: 0.601
#   AUC-ROC: 0.848

# %% [markdown]
# ## Вывод

# %% [markdown]
# Нам удалось обучить модель для прогнозирования оттока клиентов из «Бета-Банка», благодаря чему у банка будет возможность повлиять на решение клиента.
#
# Наилучшей моделью оказлся "случайный лес" (глубина деревьев = 23, количество деревьев = 31)  с показателем F1 = 0.601 обученная на сбалансированной выборке.
#
# Кроме методов сбалансирования при подготовке данных применялиьс алгоритмы прямого кодирования категориальных признаков и стандартизация числовых признаков, а так же была проделана работа по анализу корреляций признаков, обработке пропусков, изменению типов данных, отбору необходимых признаков.
